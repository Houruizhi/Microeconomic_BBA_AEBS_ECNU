# %%
import xlrd
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
path = 'Anwser_Behavioral_Finance_Pre-course_survey.xlsx'

# %%
def load_survey(path):
    survey = xlrd.open_workbook(path)
    table = survey.sheet_by_name('Sheet0')
    return table

# %%
table = load_survey(path)
col_values = table.col_values(2)
print(col_values)
title_name = col_values[0]
# Out:
# ['Can you explain “efficient market hypothesis (EMH)”?', '', '', '', '', '', '', 'Yes', '', '', '', '', '', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', '', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'No', '', 'Yes', 'No', 'No', '', 'Yes', 'No', '', '']

# %%
def count_num(data):
    value_vs_number = {}
    for i in data:
        i = i.split(',')[0]
        if i in value_vs_number.keys():
            value_vs_number[i] += 1
        else:
            value_vs_number[i] = 1
    return value_vs_number

# %%
def load_data(path, colume):
    table = load_survey(path)
    col_values = table.col_values(colume)
    title = col_values[0].split("、")[-1]
    col_values = col_values[1:]
    return col_values, title
def draw_figure(data,order=None,palette = ['red','blue']):
    xx = list(data.values())
    index = np.argsort(xx)
    xx.sort(reverse=True)
    yy = [list(data.keys())[i] for i in index[::-1]]
    ax = sns.barplot(x=xx,y=yy, order=order, orient='h', palette=palette)
    ax.set_xlabel("Number of Students", fontsize=14)
    if order==None:
        patches = ax.patches
    else:
        patches = ax.patches[:len(order)]
    total = 0
    for i in patches:
        total += i.get_width()
    ax.set_xticks(list(range(0,int(ax.patches[0].get_width())+21,5)))
    for i in patches:
        ax.text(i.get_width(), i.get_y()+0.5, f'{str(int(i.get_width()))}({str(round((i.get_width()/total)*100, 2))}%)', fontsize=12, color='gray')
    return ax

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,2)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/emh.png'
plt.savefig(save_path,bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,4)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/arbitrage.png'
plt.savefig(save_path, bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,5)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/prospect_theory.png'
plt.savefig(save_path, bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,6)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/equity_premium_puzzle.png'
plt.savefig(save_path, bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,7)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/nudge.png'
plt.savefig(save_path, bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,8)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/experimental_economics.png'
plt.savefig(save_path, bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,9)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/design_experiment.png'
plt.savefig(save_path, bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,10)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/implement_oTree.png'
plt.savefig(save_path, bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,12)
data = count_num(col_values)
del data['']
draw_figure(data)
plt.title(title)
save_path = './pictures/research.png'
plt.savefig(save_path, bbox_inches='tight')

# %%
plt.figure(dpi=100)
col_values, title = load_data(path,13)
data = []
for i in col_values:
    if i == '':
        continue
    else:
        data.append(str(int(i)))
data = count_num(data)
xx = list(data.values())
index = np.argsort(xx)
xx.sort(reverse=True)
yy = [list(data.keys())[i] for i in index[::-1]]
yy = [int(i) for i in yy]
ax = sns.barplot(x=yy,y=xx)
ax.set_xlabel("Number of Students", fontsize=14)
ax.set_ylabel("Score", fontsize=14)
plt.title(title)
save_path = './pictures/rank_yourself.png'
plt.savefig(save_path, bbox_inches='tight')
